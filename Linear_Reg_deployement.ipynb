# %%
import pandas as pd
import pickle
data=pd.read_csv("CKD.csv")
data=pd.get_dummies(data,dtype=int,drop_first=True)

# %%
data
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
input=data.iloc[1:2,0:27].values

# %%
input
# Out:
# array([[3.00000000e+00, 7.64599483e+01, 2.00000000e+00, 0.00000000e+00,
#         1.48112676e+02, 2.20000000e+01, 7.00000000e-01, 1.37528754e+02,
#         4.62724359e+00, 1.07000000e+01, 3.40000000e+01, 1.23000000e+04,
#         4.70559701e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
scx=pickle.load(open("preprocessing_file.sav",'rb'))

# %%
preinput=scx.transform(input)
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open("Classification_Linear_Regression.sav",'rb'))

# %%
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([1])
