# %%
import pandas as pd

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
dependent=dataset[['classification_yes']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
X_train=scx.fit_transform(X_train)
X_test=scx.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
param_grid={'kernel':['rbf','poly','linear','sigmoid'],'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}
grid=GridSearchCV(SVC(probability=True),param_grid,verbose=3,cv=5,n_jobs=1,scoring='f1_weighted')
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=auto, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=auto, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=auto, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=auto, kernel=poly;, score=1.000 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=auto, kernel=poly;, score=1.000 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=auto, kernel=poly;, score=0.964 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=auto, kernel=poly;, score=1.000 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=auto, kernel=poly;, score=0.982 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=auto, kernel=linear;, score=0.982 total time=   0.0s
# ...

# %%
cl=grid.cv_results_

# %%
print(cl)
# Out:
# {'mean_fit_time': array([0.00473952, 0.00590096, 0.00340004, 0.00350137, 0.00480366,
#        0.00630322, 0.00280323, 0.0037168 , 0.00356092, 0.00630188,
#        0.00290294, 0.00339952, 0.0036006 , 0.00579395, 0.00319204,
#        0.0034997 , 0.0032011 , 0.00587797, 0.00339885, 0.00360508,
#        0.00339828, 0.00579143, 0.0027925 , 0.00379438, 0.00360188,
#        0.00604076, 0.00319953, 0.00339932, 0.00360041, 0.00629253,
#        0.00290246, 0.00379944, 0.00359955, 0.00630112, 0.00279989,
#        0.00360026, 0.00359931, 0.00623145, 0.00379996, 0.0042007 ]), 'std_fit_time': array([0.00201504, 0.00019608, 0.00049139, 0.00063596, 0.00098513,
#        0.00060837, 0.00040142, 0.00039185, 0.00050569, 0.0011765 ,
#        0.00019465, 0.00048996, 0.00049184, 0.00040212, 0.00116051,
#        0.0004462 , 0.00075003, 0.00045469, 0.00049047, 0.0004902 ,
#        0.00049186, 0.0003963 , 0.00040057, 0.00117236, 0.00050554,
#        0.00063996, 0.00039985, 0.00048953, 0.00102074, 0.00058206,
# ...

# %%
grid_prediction=grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,grid_prediction)

# %%
print(cm)
# Out:
# [[45  0]
#  [ 2 73]]

# %%
from sklearn.metrics import classification_report
clf=classification_report(Y_test,grid_prediction)

# %%
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        45
#            1       1.00      0.97      0.99        75
#
#     accuracy                           0.98       120
#    macro avg       0.98      0.99      0.98       120
# weighted avg       0.98      0.98      0.98       120

# %%
from sklearn.metrics import f1_score
f1_weight=f1_score(Y_test,grid_prediction,average='weighted')
print("The parameters for best f1 score {}".format(grid.best_params_),f1_weight)
# Out:
# The parameters for best f1 score {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'} 0.9834018801410106

# %%
from sklearn.metrics import roc_auc_score
roc=roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])

# %%
roc
# Out:
# 0.9997037037037036
